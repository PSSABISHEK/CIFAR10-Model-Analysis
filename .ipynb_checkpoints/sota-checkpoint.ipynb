# %%
import numpy as np
import matplotlib.pyplot as plt
import time

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms, datasets
from torch.autograd import Variable

# %%
print(torch.__version__)
# Out:
# 1.8.0

# %% [markdown]
# # TUTORIAL - **[PyTorch Training a Classifier](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#sphx-glr-beginner-blitz-cifar10-tutorial-py)**

# %%
# normalize
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
# download training dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# assign num workers and create batchsize using torch dataloader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True, num_workers=2)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)
# class labels
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# plane   cat truck plane

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
        
net = Net()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,  2000] loss: 2.222
# [1,  4000] loss: 1.999
# [1,  6000] loss: 1.785
# [1,  8000] loss: 1.675
# [1, 10000] loss: 1.603
# [1, 12000] loss: 1.565
# [2,  2000] loss: 1.484
# [2,  4000] loss: 1.463
# [2,  6000] loss: 1.442
# [2,  8000] loss: 1.413
# [2, 10000] loss: 1.396
# [2, 12000] loss: 1.373
# Finished Training

# %%
# save model
PATH = './saved_models/stock_model.pt'
torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)
print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat plane  ship plane

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 50 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 66 %
# Accuracy of   car : 59 %
# Accuracy of  bird : 46 %
# Accuracy of   cat : 26 %
# Accuracy of  deer : 51 %
# Accuracy of   dog : 46 %
# Accuracy of  frog : 71 %
# Accuracy of horse : 48 %
# Accuracy of  ship : 46 %
# Accuracy of truck : 44 %

# %% [markdown]
# # CONTRIBUTION

# %% [markdown]
# ### BATCH SIZE = 32
# ### TESTLOADER SHUFFEL = TRUE

# %%
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip(),transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
transform_test = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)

torch.manual_seed(43)
val_size = 5000
train_size = len(dataset) - val_size
trainset, validationset = torch.utils.data.random_split(dataset, [train_size, val_size])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=256, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(validationset, batch_size=256, shuffle=True, num_workers=2)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=256, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(len(trainloader))
print(len(valloader))
print(len(testloader))
# Out:
# 88
# 10
# 20

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ### SETTING TO TRAIN THE MODEL USING GPU

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %% [markdown]
# ### DISPLAYING IMAGES IN ONE BATCH

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 3, 32, 32])
# torch.Size([32])

# %%
def fit(epochs, model, learning_rate=0.01, w_decay=0.9, loss_func=nn.CrossEntropyLoss()):
    
    running_train_loss = []
    running_train_accuracy = []
    
    running_test_accuracy = []
    
    running_val_accuracy = []
    running_val_loss = []
    
    criterion = loss_func
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    start = time.time()
    
    for e in range(epochs): # training our model, put input according to every batch.

        running_loss = 0.0
        running_corrects = 0.0
        end = 0.0
        batch_loss = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):
            inputs = inputs.to(device) # input to device as our model is running in mentioned device.
            labels = labels.to(device)
            
            optimizer.zero_grad() #setting the initial gradient to 0
            
            outputs = model(inputs)
            loss = criterion(outputs, labels) # Calc loss after each batch i/p by comparing it to actual labels. 
            loss.backward() # backpropagating the loss
            optimizer.step() # updating the weights and bias values for every single step.
            end = time.time()
            
            running_loss += outputs.shape[0] * loss.item()
            batch_loss += loss.item()
            if i > 0 and i % 75 == 0:
                print('Train Epoch: {} [{}/{}\t({:.0f}%)]\tLoss: {:.3f}'.format(e+1, i * len(inputs), len(trainloader.dataset), 
                                                                                100. * i / len(trainloader), batch_loss / 75))
                batch_loss = 0.0
            
            _, preds = torch.max(outputs.data, 1) # taking the highest value of prediction.
            running_corrects += torch.sum(preds == labels) # calculating te accuracy by taking the sum of all the correct predictions in a batch.
        
        running_val_history = model_validate(model, loss_func)
        epoch_loss = running_loss / len(trainloader.dataset) # loss per epoch
        epoch_acc = running_corrects / len(trainloader.dataset) # accuracy per epoch
        
        running_train_loss.append(epoch_loss) # appending for displaying 
        running_train_accuracy.append(epoch_acc) # appending for displaying
        
        running_val_loss.append(running_val_history['val_loss'])
        running_val_accuracy.append(running_val_history['val_acc'])
        

        print('Epoch :', (e+1))
        print('Training loss: {:.3f}, acc {:.3f}, Time: {:.3f} seconds'.format(epoch_loss, epoch_acc, end - start))
        print('Validation loss: {:.3f}, acc {:.3f}'.format(running_val_history['val_loss'], running_val_history['val_acc']))
        running_test_accuracy.append(model_test(model))
        print('------------------------------------------------------')
        start = time.time()
        
        
    print("Training Completed")
    return running_train_loss, running_train_accuracy, running_test_accuracy, running_val_loss, running_val_accuracy

# %%
def model_validate(model, loss_func):
    val_loss = 0.0
    loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = loss_func(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return {'val_loss': val_loss / len(valloader), 'val_acc': correct / total}

# %%
def model_test(model):
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
    print('Test Accuracy: {:.3f}'.format(correct/total))    
    return correct/total

# %%
def save_model(model_name, model):
    PATH = './'+str(model_name)+'.pt'
    torch.save(model.state_dict(), PATH)
    print('Model Saved')

# %%
# model 2_layers

class Model_2(nn.Module):
    def __init__(self):
        super(Model_2, self).__init__()
        self.network = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            # Conv Layer block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8
            
            nn.Flatten(), 
            nn.Linear(128*8*8, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        return self.network(x)
    
layer_2_model = Model_2().to(device)

# %%
# model 2_layers Less neurons in fc

class Model_2a(nn.Module):
    def __init__(self):
        super(Model_2a, self).__init__()
        self.network = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2), # output: 64 x 16 x 16

            # Conv Layer block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2), # output: 128 x 8 x 8
            
            nn.Flatten(), 
            nn.Linear(128*8*8, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        return self.network(x)
    
layer_2a_model = Model_2a().to(device)

# %%
# model 3_layers

class Model_3a(nn.Module):   
    def __init__(self):
        super(Model_3a, self).__init__()
        self.conv_layer = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv Layer block 2
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.05),

            # Conv Layer block 3
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),
            nn.Linear(4096, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(512, 10)
        )


    def forward(self, x):
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layer
        x = self.fc_layer(x)

        return x

layer_3a_model = Model_3a().to(device)

# %%
# model 3b_layers kernel size 5

class Model_3b(nn.Module):   
    def __init__(self):
        super(Model_3b, self).__init__()
        self.conv_layer = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 64 x 14 x 14

            # Conv Layer block 2
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 128 x 7 x 7
            nn.Dropout2d(p=0.05),

            # Conv Layer block 3
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=5, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=5, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # output: 256 x 1 x 1
        )
#         nout = [n_input - kernal_size + 2*padding / stride] + 1

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),            
            nn.Linear(256*1*1, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(512, 10)
        )


    def forward(self, x):
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layer
        x = self.fc_layer(x)

        return x

layer_3b_model = Model_3b().to(device)

# %%
# model 3c_layers kernel size 5

class Model_3c(nn.Module):   
    def __init__(self):
        super(Model_3c, self).__init__()
        self.conv_layer = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 64 x 14 x 14

            # Conv Layer block 2
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 128 x 7 x 7
            nn.Dropout2d(p=0.05),     

            # Conv Layer block 3
            nn.Conv2d(in_channels=128, out_channels=512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),  # output: 512 x 3 x 3
        )

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),            
            nn.Linear(512*3*3, 128),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(128, 10)
        )


    def forward(self, x):
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layer
        x = self.fc_layer(x)

        return x

layer_3c_model = Model_3c().to(device)

# %%
# model 4a_layers kernel size 5 and 3

class Model_4a(nn.Module):   
    def __init__(self):
        super(Model_4a, self).__init__()
        self.conv_layer = nn.Sequential(
            # Conv Layer block 1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 64 x 16 x 16

            # Conv Layer block 2
            nn.Conv2d(in_channels=64, out_channels=1024, kernel_size=3, padding=1),
            nn.BatchNorm2d(1024),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # output: 1024 x 8 x 8
            nn.Dropout2d(p=0.05),     

            # Conv Layer block 3
            nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3),  # output: 1024 x 4 x 4
            
            # Conv Layer block 4
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=512, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=3),  # output: 128 x 2 x 2
            
        )

        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),            
            nn.Linear(128*2*2, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.3),
            nn.Linear(512, 10)
        )


    def forward(self, x):
        """Perform forward."""

        # conv layers
        x = self.conv_layer(x)

        # flatten
        x = x.view(x.size(0), -1)

        # fc layer
        x = self.fc_layer(x)

        return x

layer_4a_model = Model_4a().to(device)

# %%
loss_list_2, acc_list_2, test_acc_2 = fit(15, 0.001, layer_2_model)
# Out:
# Train Epoch: 1 [12800/50000	(26%)]	Loss: 2.314
# Train Epoch: 1 [25600/50000	(51%)]	Loss: 2.304
# Train Epoch: 1 [38400/50000	(77%)]	Loss: 2.303
# epoch : 1
# training loss: 2.303, acc 0.100 ,Time: 25.209 seconds
# Train Epoch: 2 [12800/50000	(26%)]	Loss: 2.314
# Train Epoch: 2 [25600/50000	(51%)]	Loss: 2.303
# Train Epoch: 2 [38400/50000	(77%)]	Loss: 2.303
# epoch : 2
# training loss: 2.303, acc 0.100 ,Time: 24.976 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-f309b53ea831> in <module>
# ----> 1 loss_list_2, acc_list_2, test_acc_2 = fit(15, 0.001, layer_2_model)
#
# <ipython-input-43-7ddab6adf66c> in fit(epochs, learning_rate, model, loss_func)
#      44         print('epoch :', (e+1))
#      45         print('training loss: {:.3f}, acc {:.3f} ,Time: {:.3f} seconds'.format(epoch_loss, epoch_acc, end - start))
# ...

# %%
loss_list_2, acc_list_2, test_acc_2 = fit(15, 0.1, layer_2_model)
# Out:
# Train Epoch: 1 [12800/50000	(26%)]	Loss: 2.244
# Train Epoch: 1 [25600/50000	(51%)]	Loss: 1.987
# Train Epoch: 1 [38400/50000	(77%)]	Loss: 1.809
# epoch : 1
# training loss: 1.929, acc 0.292 ,Time: 27.644 seconds
# Train Epoch: 2 [12800/50000	(26%)]	Loss: 1.572
# Train Epoch: 2 [25600/50000	(51%)]	Loss: 1.464
# Train Epoch: 2 [38400/50000	(77%)]	Loss: 1.350
# epoch : 2
# training loss: 1.416, acc 0.487 ,Time: 24.842 seconds
# Train Epoch: 3 [12800/50000	(26%)]	Loss: 1.174
# Train Epoch: 3 [25600/50000	(51%)]	Loss: 1.095
# Train Epoch: 3 [38400/50000	(77%)]	Loss: 1.034
# epoch : 3
# training loss: 1.074, acc 0.617 ,Time: 24.898 seconds
# Train Epoch: 4 [12800/50000	(26%)]	Loss: 0.855
# Train Epoch: 4 [25600/50000	(51%)]	Loss: 0.864
# Train Epoch: 4 [38400/50000	(77%)]	Loss: 0.807
# epoch : 4
# training loss: 0.831, acc 0.707 ,Time: 24.919 seconds
# Train Epoch: 5 [12800/50000	(26%)]	Loss: 0.633
# Train Epoch: 5 [25600/50000	(51%)]	Loss: 0.640
# ...

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_2_model)))
# Out:
# Accuracy of the network on the 10000 test images: 75 %

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list_2, color='red', label='training')
plt.plot(np.arange(0, 15, 1), test_acc_2, color='blue', label='test')
plt.legend()
plt.show()

# %%
save_model("layer_2_model", layer_2_model)
# Out:
# Model Saved

# %% [markdown]
# ## OVERFITTING

# %%
loss_list, acc_list, test_acc = fit(15, 0.01, layer_2a_model)
# Out:
# Train Epoch: 1 [12800/50000	(26%)]	Loss: 0.838
# Train Epoch: 1 [25600/50000	(51%)]	Loss: 0.836
# Train Epoch: 1 [38400/50000	(77%)]	Loss: 0.833
# epoch : 1
# training loss: 0.838, acc 0.705 ,Time: 21.833 seconds
# Train Epoch: 2 [12800/50000	(26%)]	Loss: 0.781
# Train Epoch: 2 [25600/50000	(51%)]	Loss: 0.781
# Train Epoch: 2 [38400/50000	(77%)]	Loss: 0.800
# epoch : 2
# training loss: 0.786, acc 0.723 ,Time: 21.857 seconds
# Train Epoch: 3 [12800/50000	(26%)]	Loss: 0.736
# Train Epoch: 3 [25600/50000	(51%)]	Loss: 0.718
# Train Epoch: 3 [38400/50000	(77%)]	Loss: 0.746
# epoch : 3
# training loss: 0.738, acc 0.739 ,Time: 22.083 seconds
# Train Epoch: 4 [12800/50000	(26%)]	Loss: 0.696
# Train Epoch: 4 [25600/50000	(51%)]	Loss: 0.690
# Train Epoch: 4 [38400/50000	(77%)]	Loss: 0.694
# epoch : 4
# training loss: 0.690, acc 0.758 ,Time: 21.858 seconds
# Train Epoch: 5 [12800/50000	(26%)]	Loss: 0.629
# Train Epoch: 5 [25600/50000	(51%)]	Loss: 0.638
# ...

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_2a_model)))
# Out:
# Accuracy of the network on the 10000 test images: 67 %

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list, color='red')
plt.plot(np.arange(0, 15, 1), test_acc, color='blue')

# %%
save_model("layer_2a_model", layer_2a_model)
# Out:
# Model Saved

# %%
loss_list_3a, acc_list_3a, test_acc_3a = fit(15, 0.01, layer_3a_model)
# Out:
# Train Epoch: 1 [12800/50000	(26%)]	Loss: 2.211
# Train Epoch: 1 [25600/50000	(51%)]	Loss: 1.752
# Train Epoch: 1 [38400/50000	(77%)]	Loss: 1.563
# epoch : 1
# training loss: 1.744, acc 0.359 ,Time: 30.604 seconds
# Train Epoch: 2 [12800/50000	(26%)]	Loss: 1.339
# Train Epoch: 2 [25600/50000	(51%)]	Loss: 1.264
# Train Epoch: 2 [38400/50000	(77%)]	Loss: 1.174
# epoch : 2
# training loss: 1.225, acc 0.550 ,Time: 30.248 seconds
# Train Epoch: 3 [12800/50000	(26%)]	Loss: 1.046
# Train Epoch: 3 [25600/50000	(51%)]	Loss: 0.996
# Train Epoch: 3 [38400/50000	(77%)]	Loss: 0.936
# epoch : 3
# training loss: 0.973, acc 0.651 ,Time: 30.260 seconds
# Train Epoch: 4 [12800/50000	(26%)]	Loss: 0.853
# Train Epoch: 4 [25600/50000	(51%)]	Loss: 0.834
# Train Epoch: 4 [38400/50000	(77%)]	Loss: 0.800
# epoch : 4
# training loss: 0.813, acc 0.712 ,Time: 30.211 seconds
# Train Epoch: 5 [12800/50000	(26%)]	Loss: 0.724
# Train Epoch: 5 [25600/50000	(51%)]	Loss: 0.705
# ...

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_3a_model)))
# Out:
# Accuracy of the network on the 10000 test images: 79 %

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list_3a, color='red')
plt.plot(np.arange(0, 15, 1), test_acc_3a, color='blue')

# %%
save_model("layer_3a_model", layer_3a_model)
# Out:
# Model Saved

# %%
loss_list_3b, acc_list_3b, test_acc_3b = fit(15, 0.01, layer_3b_model)
# Out:
# Train Epoch: 1 [12800/50000	(26%)]	Loss: 2.203
# Train Epoch: 1 [25600/50000	(51%)]	Loss: 1.783
# Train Epoch: 1 [38400/50000	(77%)]	Loss: 1.588
# epoch : 1
# training loss: 1.760, acc 0.342 ,Time: 39.165 seconds
# Test Accuracy: 0.409
# Train Epoch: 2 [12800/50000	(26%)]	Loss: 1.312
# Train Epoch: 2 [25600/50000	(51%)]	Loss: 1.212
# Train Epoch: 2 [38400/50000	(77%)]	Loss: 1.143
# epoch : 2
# training loss: 1.189, acc 0.564 ,Time: 36.208 seconds
# Test Accuracy: 0.555
# Train Epoch: 3 [12800/50000	(26%)]	Loss: 0.982
# Train Epoch: 3 [25600/50000	(51%)]	Loss: 0.941
# Train Epoch: 3 [38400/50000	(77%)]	Loss: 0.906
# epoch : 3
# training loss: 0.922, acc 0.670 ,Time: 36.397 seconds
# Test Accuracy: 0.654
# Train Epoch: 4 [12800/50000	(26%)]	Loss: 0.776
# Train Epoch: 4 [25600/50000	(51%)]	Loss: 0.766
# Train Epoch: 4 [38400/50000	(77%)]	Loss: 0.751
# epoch : 4
# training loss: 0.755, acc 0.734 ,Time: 36.329 seconds
# Test Accuracy: 0.706
# ...

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_3b_model)))
# Out:
# Test Accuracy: 0.744
# Accuracy of the network on the 10000 test images: 74 %

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list_3c, color='red')
plt.plot(np.arange(0, 15, 1), test_acc_3c, color='blue')

# %%
save_model("layer_3b_model", layer_3b_model)
# Out:
# Model Saved

# %%
loss_list_3c, acc_list_3c, test_acc_3c, val_loss_3c, val_acc_3c = fit(20, layer_3c_model, 0.001)
# Out:
# Train Epoch: 1 [8000/45000	(18%)]	Loss: 1.931
# Train Epoch: 1 [16000/45000	(36%)]	Loss: 1.722
# Train Epoch: 1 [24000/45000	(53%)]	Loss: 1.617
# Train Epoch: 1 [32000/45000	(71%)]	Loss: 1.544
# Train Epoch: 1 [40000/45000	(89%)]	Loss: 1.481
# Epoch : 1
# Training loss: 1.633, acc 0.397, Time: 67.146 seconds
# Validation loss: 1.392, acc 0.485
# Test Accuracy: 0.493
# ------------------------------------------------------
# Train Epoch: 2 [8000/45000	(18%)]	Loss: 1.366
# Train Epoch: 2 [16000/45000	(36%)]	Loss: 1.316
# Train Epoch: 2 [24000/45000	(53%)]	Loss: 1.291
# Train Epoch: 2 [32000/45000	(71%)]	Loss: 1.240
# Train Epoch: 2 [40000/45000	(89%)]	Loss: 1.213
# Epoch : 2
# Training loss: 1.272, acc 0.545, Time: 67.052 seconds
# Validation loss: 1.190, acc 0.585
# Test Accuracy: 0.587
# ------------------------------------------------------
# Train Epoch: 3 [8000/45000	(18%)]	Loss: 1.119
# Train Epoch: 3 [16000/45000	(36%)]	Loss: 1.086
# ...

# %%
save_model("layer_3c_model", layer_3c_model)
# Out:
# Model Saved

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 20, 1), acc_list_3c, color='red', labels='Train')
plt.plot(np.arange(0, 20, 1), test_acc_3c, color='blue', labels='Test')
plt.plot(np.arange(0, 20, 1), val_acc_3c, color='green', labels='Val')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-153a35276624> in <module>()
#       2 plt.xlabel('epochs')
#       3 plt.ylabel('accuracy')
# ----> 4 plt.plot(np.arange(0, 20, 1), acc_list_3c, color='red', labels='Train')
#       5 plt.plot(np.arange(0, 20, 1), test_acc_3c, color='blue', labels='Test')
#       6 plt.plot(np.arange(0, 20, 1), val_acc_3c, color='green', labels='Val')
#
# NameError: name 'acc_list_3c' is not defined

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 13, 1), acc_list_3c, color='red')
plt.plot(np.arange(0, 13, 1), test_acc_3c, color='blue')

# %%
loss_list_4a, acc_list_4a, test_acc_4a, val_loss_4a, val_acc_4a = fit(20, layer_4a_model, 0.001)
# Out:
# Train Epoch: 1 [19200/45000	(43%)]	Loss: 1.962
# Train Epoch: 1 [38400/45000	(85%)]	Loss: 1.658
# Epoch : 1
# Training loss: 1.756, acc 0.306, Time: 78.265 seconds
# Validation loss: 1.492, acc 0.439
# Test Accuracy: 0.449
# ------------------------------------------------------
# Train Epoch: 2 [19200/45000	(43%)]	Loss: 1.438
# Train Epoch: 2 [38400/45000	(85%)]	Loss: 1.240
# Epoch : 2
# Training loss: 1.307, acc 0.519, Time: 78.291 seconds
# Validation loss: 1.133, acc 0.593
# Test Accuracy: 0.593
# ------------------------------------------------------
# Train Epoch: 3 [19200/45000	(43%)]	Loss: 1.081
# Train Epoch: 3 [38400/45000	(85%)]	Loss: 0.969
# Epoch : 3
# Training loss: 1.005, acc 0.644, Time: 78.240 seconds
# Validation loss: 0.918, acc 0.677
# Test Accuracy: 0.682
# ------------------------------------------------------
# Train Epoch: 4 [19200/45000	(43%)]	Loss: 0.889
# Train Epoch: 4 [38400/45000	(85%)]	Loss: 0.821
# Epoch : 4
# ...

# %% [markdown]
# ### 4 Layers with 2 FC Layer and no Dropout.

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 12, 1), acc_list_4a, color='red')
plt.plot(np.arange(0, 12, 1), test_acc_4a, color='blue')
plt.plot(np.arange(0, 12, 1), val_acc_4a, color='green')

# %% [markdown]
# ### 4 Layers with 3 FC layer and Dropout 0.3

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 15, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 15, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 20, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 20, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 20, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 6, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 6, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 6, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
#Run 4 BatchSize 512 Epoch 15
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 15, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 15, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 15, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
#Run 5 BatchSize 256 Epoch 10
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 10, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 10, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 10, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
#Run 6 BatchSize 256 Epoch 20
plt.figure(figsize=(10, 5))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(0, 20, 1), acc_list_4a, color='red', label='Train')
plt.plot(np.arange(0, 20, 1), test_acc_4a, color='blue', label='Test')
plt.plot(np.arange(0, 20, 1), val_acc_4a, color='green', label='Val')
plt.legend(loc="upper left")

# %%
save_model("layer_4a_model", layer_4a_model)
# Out:
# Model Saved

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_4a_model)))
# Out:
# Test Accuracy: 0.834
# Accuracy of the network on the 10000 test images: 83 %

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_4a_model)))
# Out:
# Test Accuracy: 0.857
# Accuracy of the network on the 10000 test images: 85 %

# %%
# Run 4
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_4a_model)))
# Out:
# Test Accuracy: 0.867
# Accuracy of the network on the 10000 test images: 86 %

# %%
# Run 6
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_4a_model)))
# Out:
# Test Accuracy: 0.867
# Accuracy of the network on the 10000 test images: 86 %

# %% [markdown]
# ### BEST ACCURACY REACHED TILL NOW

# %%
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * model_test(layer_4a_model)))
# Out:
# Test Accuracy: 0.880
# Accuracy of the network on the 10000 test images: 88 %

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()
images = images.to(device)
labels = labels.to(device)

# print images
# imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(16)))
outputs = layer_4a_model(images)
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(16)))
# Out:
# GroundTruth:   frog  bird  ship  frog  deer   cat   cat  deer  frog plane  deer  bird  ship  frog   cat  bird
# Predicted:   frog  bird  ship  frog  deer   cat   cat  deer  frog  bird  deer  bird  ship  frog   dog  frog

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = layer_4a_model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 100 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 81 %
# Accuracy of  deer : 90 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 100 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 81 %

# %% [markdown]
# ## MODELS AGAINST TRAINING TIME PER EPOCH

# %%
time = [25, 21, 30, 39, 35, 86, 86, 81, 77, 81]
models = ['2', '2A', '2C', '3A', '3B', '3C', '4A', '4B', '4C', '4D' ]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
barlist = ax.bar(models, time)
barlist[7].set_color('g')
plt.xlabel('Models')
plt.ylabel('Time per epoch (sec)')
plt.title('Model vs Trianing time per epoch')
plt.show()
